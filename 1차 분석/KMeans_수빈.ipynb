# 39    61.329073    7,768       710  0.091401        0.185911
# 40   438.931932   44,949      4081  0.090792        4.983977
# 41   503.901277    10395       943  0.090717        8.166270
# 42   388.689272   25,894      2347  0.090639        1.727014
# 43  1323.236172   29,619      2636  0.088997        9.943755
# 44  2933.900045   27,836      2405  0.086399       20.925417
# 45   175.419750    3,275       278  0.084885        0.435331
# 46   177.367433    8,908       749  0.084082        3.180926
# 47   953.449338   11,054       923  0.083499       11.145593
# 48  1194.013090    8,599       711  0.082684        8.585505
# 49  1294.840705    9,432       779  0.082591        9.995253
# 50   758.841272   34,526      2733  0.079158        4.980818
# 51   461.521520   41,509      3214  0.077429        4.915531
# 52   259.148472   30,108      2281  0.075761        1.862187
# 53   751.357779    7,499       541  0.072143        2.897666
# 54  1165.624324  180,795      1186  0.006560       12.832720

# %%
df1 = data.loc[:, ['traffic/area', 'avg_temp', 'dust_naver', 'f_pop/area', 'young_old/area']]
df1.head()
# Out:
#    traffic/area   avg_temp  dust_naver  f_pop/area  young_old/area
# 0      4.205007  24.724592          23   42.515128        1.239300
# 1      0.556901  24.234239          23    0.101695        0.084618
# 2      1.292627  25.002491           7   31.810829        1.000228
# 3      4.942185  24.528216          21   18.904999        0.763345
# 4     13.589966  24.548234          23  171.009630        4.750404

# %% [markdown]
# ## 데이터셋 정규화 -> 정규화o:df 정규화x:df1

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaled = scaler.fit_transform(df1)

# %%
df = pd.DataFrame(scaled)
df.columns=df1.columns
df.head()
# Out:
#    traffic/area  avg_temp  dust_naver  f_pop/area  young_old/area
# 0      0.015736  0.526044    0.954545    0.014457        0.052534
# 1      0.000000  0.267464    0.954545    0.000000        0.000000
# 2      0.003173  0.672590    0.227273    0.010808        0.041657
# 3      0.018915  0.422488    0.863636    0.006409        0.030880
# 4      0.056217  0.433044    0.954545    0.058255        0.212278

# %% [markdown]
# ## Elbow method -> 군집 개수 3개가 적절

# %%
wcss = []
for i in range(1,11):
   model = KMeans(n_clusters = i, init = "k-means++")
   model.fit(df)
   wcss.append(model.inertia_)
plt.figure(figsize=(10,10))
plt.plot(range(1,11), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# C:\Users\lsb97_s4gev10\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# ## pca 차원축소(2)

# %%
pca = PCA(2)
data = pca.fit_transform(df)

# %% [markdown]
# ## 군집화 결과

# %%
centers = np.array(model.cluster_centers_)
model = KMeans(n_clusters = 3, init = "k-means++")
label = model.fit_predict(data)
plt.figure(figsize=(5,5))
uniq = np.unique(label)
for i in uniq:
   plt.scatter(data[label == i , 0] , data[label == i , 1] , label = i)
plt.scatter(centers[:,0], centers[:,1], marker="x", color='k')
#This is done to find the centroid for each clusters.
plt.legend()
plt.show()
#별로 성능 안좋아보임

# %%
model.inertia_
# Out:
# 3.921837591507727

# %%
cluster = pd.Series(label)

# %%
cluster
# Out:
# 0     1
# 1     1
# 2     0
# 3     1
# 4     1
# 5     1
# 6     1
# 7     1
# 8     2
# 9     0
# 10    1
# 11    1
# 12    0
# 13    1
# 14    0
# 15    0
# 16    1
# 17    2
# 18    1
# 19    1
# 20    1
# 21    2
# 22    2
# 23    1
# 24    2
# 25    0
# 26    1
# 27    0
# 28    0
# 29    2
# 30    2
# 31    2
# 32    1
# 33    0
# 34    1
# 35    1
# 36    0
# 37    0
# 38    2
# 39    1
# 40    0
# 41    1
# 42    0
# 43    2
# 44    2
# 45    1
# 46    0
# 47    2
# 48    1
# 49    2
# 50    0
# 51    0
# 52    0
# 53    0
# 54    2
# dtype: int32

# %%
df1['cluster'] = cluster

# %%
df1['cluster'].value_counts()
# Out:
# 1    23
# 0    18
# 2    14
# Name: cluster, dtype: int64

# %%
import pandas as pd

df2 = pd.DataFrame(columns = df1.columns[:-1])
df2
# Out:
# Empty DataFrame
# Columns: [traffic/area, avg_temp, dust_naver, f_pop/area, young_old/area]
# Index: []

# %%
c1=[]
c2=[]
c3=[]
c4=[]
c5=[]

for i in range(3):    
    c1.append(df1[df1['cluster']==i]['traffic/area'].mean())
    c2.append(df1[df1['cluster']==i]['avg_temp'].mean())
    c3.append(df1[df1['cluster']==i]['dust_naver'].mean())
    c4.append(df1[df1['cluster']==i]['f_pop/area'].mean())
    c5.append(df1[df1['cluster']==i]['young_old/area'].mean())

# %%
df2['traffic/area']=c1
df2['avg_temp']=c2
df2['dust_naver']=c3
df2['f_pop/area']=c4
df2['young_old/area']=c5

# %% [markdown]
# ## 각 군집별 항목 평균 -> 최종적으로 cluster1 선정이 적합

# %%
#군집별특징
df2
# Out:
#    traffic/area   avg_temp  dust_naver   f_pop/area  young_old/area
# 0     23.170666  25.111780    9.500000   244.799714        2.421662
# 1     40.099654  24.753720   22.478261   252.057145        3.568901
# 2    111.645692  25.284705   15.500000  1282.686494       14.714573

# %%
data = pd.read_csv('C:/창원시/final_data.csv')

df1['address']=data['address']

# %%
df1.head()
# Out:
#    traffic/area   avg_temp  dust_naver  f_pop/area  young_old/area  cluster  \
# 0      4.205007  24.724592          23   42.515128        1.239300        1
# 1      0.556901  24.234239          23    0.101695        0.084618        1
# 2      1.292627  25.002491           7   31.810829        1.000228        0
# 3      4.942185  24.528216          21   18.904999        0.763345        1
# 4     13.589966  24.548234          23  171.009630        4.750404        1
#
#      address
# 0   마산합포구 현동
# 1  마산합포구 진전면
# 2     의창구 북면
# 3    진해구 웅천동
# 4    진해구 풍호동

# %%
dong0 = []
dong1 = []
dong2 = []
data = pd.read_csv('C:/창원시/final_data.csv')
for i in range(len(df1)):
    if df1.iloc[i]['cluster']==0:
        dong0.append(df1.iloc[i]['address'])
    elif df1.iloc[i]['cluster']==1:
        dong1.append(df1.iloc[i]['address'])
    else:
        dong2.append(df1.iloc[i]['address'])

# %% [markdown]
# ## cluster1에 해당되는 동 출력

# %%
dong0
# Out:
# ['의창구 북면',
#  '진해구 충무동',
#  '진해구 여좌동',
#  '진해구 웅동1동',
#  '진해구 웅동2동',
#  '마산회원구 합성1동',
#  '의창구 의창동',
#  '의창구 동읍',
#  '마산회원구 내서읍',
#  '마산회원구 회성동',
#  '성산구 성주동',
#  '성산구 사파동',
#  '의창구 팔룡동',
#  '마산회원구 구암1동',
#  '성산구 중앙동',
#  '의창구 명곡동',
#  '의창구 봉림동',
#  '마산회원구 합성2동']

# %%
dong1
# Out:
# ['마산합포구 가포동',
#  '마산합포구 교방동',
#  '마산합포구 구산면',
#  '마산합포구 문화동',
#  '마산합포구 완월동',
#  '마산합포구 월영동',
#  '마산합포구 진동면',
#  '마산합포구 진북면',
#  '마산합포구 진전면',
#  '마산합포구 현동',
#  '마산회원구 봉암동',
#  '마산회원구 회원2동',
#  '성산구 웅남동',
#  '의창구 대산면',
#  '진해구 경화동',
#  '진해구 덕산동',
#  '진해구 병암동',
#  '진해구 석동',
#  '진해구 웅천동',
#  '진해구 이동',
#  '진해구 자은동',
#  '진해구 태백동',
#  '진해구 풍호동']

# %%
dong2
# Out:
# ['마산합포구 월영동',
#  '마산회원구 양덕2동',
#  '마산합포구 합포동',
#  '마산합포구 반월중앙동',
#  '마산합포구 오동동',
#  '성산구 가음정동',
#  '마산회원구 석전동',
#  '마산회원구 회원1동',
#  '성산구 반송동',
#  '성산구 용지동',
#  '성산구 상남동',
#  '마산회원구 양덕1동',
#  '마산회원구 구암2동',
#  '마산합포구 산호동']

# %% [markdown]
# # 군집4개

# %%
pca = PCA(2)
data = pca.fit_transform(df)

# %%
centers = np.array(model.cluster_centers_)
model = KMeans(n_clusters = 4, init = "k-means++")
label = model.fit_predict(data)
plt.figure(figsize=(5,5))
uniq = np.unique(label)
for i in uniq:
   plt.scatter(data[label == i , 0] , data[label == i , 1] , label = i)
plt.scatter(centers[:,0], centers[:,1], marker="x", color='k')
#This is done to find the centroid for each clusters.
plt.legend()
plt.show()
#별로 성능 안좋아보임

# %%
model.inertia_
# Out:
# 2.6258297289344514

# %%
df1['cluster']=pd.Series(label)

# %%
df1
# Out:
#     traffic/area   avg_temp  dust_naver   f_pop/area  young_old/area  cluster  \
# 0       4.205007  24.724592          23    42.515128        1.239300        2
# 1       0.556901  24.234239          23     0.101695        0.084618        2
# 2       1.292627  25.002491           7    31.810829        1.000228        1
# 3       4.942185  24.528216          21    18.904999        0.763345        2
# 4      13.589966  24.548234          23   171.009630        4.750404        2
# 5      29.287384  24.548234          23   342.303244        4.934346        2
# 6       2.128400  24.301857          23    12.364216        0.495697        2
# 7      35.715619  24.548234          23   118.643340        5.238739        2
# 8      34.915273  25.162591          23  1228.291322       20.172942        0
# 9      14.486825  24.548234           3    91.674071        1.208735        1
# 10      1.129273  24.264991          23     8.485060        0.092627        2
# 11     39.104942  24.548234          23   169.836500        4.594056        2
# 12     20.672759  24.548234           3    72.418726        2.025391        1
# 13      0.715597  24.722464          23     1.105242        0.116735        2
# 14      2.180065  23.727038          10    15.877926        0.237348        1
# 15      5.325748  24.537319          11   225.171795        3.283539        1
# 16    143.295350  24.548234          23   254.446635        6.764716        0
# 17     80.626212  25.165399          11  1331.198966       22.064266        3
# 18    145.474116  24.548234          23   608.241927        9.205536        0
# 19     77.610355  25.162591          21   383.223567        7.087106        0
# 20      1.981660  24.849819          17    15.160188        0.248780        2
# 21    232.393393  25.162591          21  1125.336927       14.254613        0
# 22    122.285770  25.162591          23  1218.602171       15.422644        0
# 23     37.037571  25.162591          21   193.669502        3.096565        2
# 24     72.754911  25.162591          21  1382.100314       11.640786        0
# 25     48.455846  25.165399          11   204.808716        1.850953        1
# 26     12.690628  24.724592          23    18.845963        0.196467        2
# 27     22.419423  25.588179           9   319.749079        6.365304        1
# 28      2.809785  24.889493           9    12.508000        0.342726        1
# 29     38.939854  25.587183          15  1142.072383       14.297023        3
# 30     90.301725  25.165399          11   894.566138        9.363144        3
# 31    178.860615  25.162591          21   854.610799       15.083065        0
# 32     59.947477  24.548234          23   461.887738        7.345689        2
# 33      2.122298  25.161775          12    83.319467        1.138016        1
# 34     54.988108  25.162591          23   740.826180        5.271461        0
# 35     26.116920  25.162591          23   301.080401        3.185519        2
# 36     22.691574  25.165399          11    19.768794        0.600672        1
# 37      5.289799  25.587183          18    93.429764        0.988876        1
# 38     90.666811  25.587183          14  1109.781316       18.862803        3
# 39      2.872190  25.623370          24    61.329073        0.185911        2
# 40     19.178725  25.587183          15   438.931932        4.983977        1
# 41    106.681100  25.162591          21   503.901277        8.166270        0
# 42     11.226695  25.588179           7   388.689272        1.727014        1
# 43     49.662191  25.587183          15  1323.236172        9.943755        3
# 44     76.593116  25.587183           8  2933.900045       20.925417        3
# 45     26.802632  25.162591          24   175.419750        0.435331        2
# 46     89.150875  25.165399           2   177.367433        3.180926        1
# 47    152.633041  25.165399          11   953.449338       11.145593        3
# 48     95.418649  24.548234          23  1194.013090        8.585505        0
# 49    229.595699  25.165399           2  1294.840705        9.995253        3
# 50     23.112601  25.409783           8   758.841272        4.980818        1
# 51     27.147065  25.588179          10   461.521520        4.915531        1
# 52     11.658056  25.587183          14   259.148472        1.862187        1
# 53     87.851228  25.165399          11   751.357779        2.897666        1
# 54    112.811080  25.162591          21  1165.624324       12.832720        0
#
#         address
# 0      마산합포구 현동
# 1     마산합포구 진전면
# 2        의창구 북면
# 3       진해구 웅천동
# 4       진해구 풍호동
# 5       진해구 덕산동
# 6     마산합포구 진동면
# 7       진해구 자은동
# 8     마산합포구 월영동
# 9       진해구 충무동
# 10    마산합포구 진북면
# 11      진해구 경화동
# 12      진해구 여좌동
# 13    마산합포구 구산면
# 14     진해구 웅동1동
# 15     진해구 웅동2동
# 16      진해구 태백동
# 17   마산회원구 양덕2동
# 18      진해구 병암동
# 19    마산합포구 교방동
# 20      의창구 대산면
# 21    마산합포구 합포동
# 22  마산합포구 반월중앙동
# 23   마산회원구 회원2동
# 24    마산합포구 오동동
# 25   마산회원구 합성1동
# 26    마산합포구 가포동
# 27      의창구 의창동
# 28       의창구 동읍
# 29     성산구 가음정동
# 30    마산회원구 석전동
# 31   마산회원구 회원1동
# 32       진해구 석동
# 33    마산회원구 내서읍
# 34    마산합포구 문화동
# 35    마산합포구 완월동
# 36    마산회원구 회성동
# 37      성산구 성주동
# 38      성산구 반송동
# 39      성산구 웅남동
# 40      성산구 사파동
# 41    마산합포구 자산동
# 42      의창구 팔룡동
# 43      성산구 용지동
# 44      성산구 상남동
# 45    마산회원구 봉암동
# 46   마산회원구 구암1동
# 47   마산회원구 양덕1동
# 48       진해구 이동
# 49   마산회원구 구암2동
# 50      성산구 중앙동
# 51      의창구 명곡동
# 52      의창구 봉림동
# 53   마산회원구 합성2동
# 54    마산합포구 산호동

# %%
df1['cluster'].value_counts()
# Out:
# 1    18
# 2    17
# 0    12
# 3     8
# Name: cluster, dtype: int64

# %%
import pandas as pd

df2 = pd.DataFrame(columns = df1.columns[:-2])
c1=[]
c2=[]
c3=[]
c4=[]
c5=[]

# %%
for i in range(4):    
    c1.append(df1[df1['cluster']==i]['traffic/area'].mean())
    c2.append(df1[df1['cluster']==i]['avg_temp'].mean())
    c3.append(df1[df1['cluster']==i]['dust_naver'].mean())
    c4.append(df1[df1['cluster']==i]['f_pop/area'].mean())
    c5.append(df1[df1['cluster']==i]['young_old/area'].mean())
    
df2['traffic/area']=c1
df2['avg_temp']=c2
df2['dust_naver']=c3
df2['f_pop/area']=c4
df2['young_old/area']=c5

# %%
#군집별특징
df2
# Out:
#    traffic/area   avg_temp  dust_naver   f_pop/area  young_old/area
# 0    114.790727  25.009001   22.000000   888.268211       11.207280
# 1     23.170666  25.111780    9.500000   244.799714        2.421662
# 2     17.577903  24.717828   22.529412   124.274216        2.176713
# 3    101.127331  25.376291   10.875000  1372.880633       14.574657

# %%
data = pd.read_csv('C:/창원시/final_data.csv')

df1['address']=data['address']
df1.head()
# Out:
#    traffic/area   avg_temp  dust_naver  f_pop/area  young_old/area  cluster  \
# 0      4.205007  24.724592          23   42.515128        1.239300        2
# 1      0.556901  24.234239          23    0.101695        0.084618        2
# 2      1.292627  25.002491           7   31.810829        1.000228        1
# 3      4.942185  24.528216          21   18.904999        0.763345        2
# 4     13.589966  24.548234          23  171.009630        4.750404        2
#
#      address
# 0   마산합포구 현동
# 1  마산합포구 진전면
# 2     의창구 북면
# 3    진해구 웅천동
# 4    진해구 풍호동

# %%
dong0 = []
dong1 = []
dong2 = []
dong3 = []

data = pd.read_csv('C:/창원시/final_data.csv')
for i in range(len(df1)):
    if df1.iloc[i]['cluster']==0:
        dong0.append(df1.iloc[i]['address'])
    elif df1.iloc[i]['cluster']==1:
        dong1.append(df1.iloc[i]['address'])
    elif df1.iloc[i]['cluster']==2:
        dong2.append(df1.iloc[i]['address'])
    else:
        dong3.append(df1.iloc[i]['address'])

# %%
dong0
# Out:
# ['마산합포구 월영동',
#  '진해구 태백동',
#  '진해구 병암동',
#  '마산합포구 교방동',
#  '마산합포구 합포동',
#  '마산합포구 반월중앙동',
#  '마산합포구 오동동',
#  '마산회원구 회원1동',
#  '마산합포구 문화동',
#  '마산합포구 자산동',
#  '진해구 이동',
#  '마산합포구 산호동']

# %%
dong1
# Out:
# ['의창구 북면',
#  '진해구 충무동',
#  '진해구 여좌동',
#  '진해구 웅동1동',
#  '진해구 웅동2동',
#  '마산회원구 합성1동',
#  '의창구 의창동',
#  '의창구 동읍',
#  '마산회원구 내서읍',
#  '마산회원구 회성동',
#  '성산구 성주동',
#  '성산구 사파동',
#  '의창구 팔룡동',
#  '마산회원구 구암1동',
#  '성산구 중앙동',
#  '의창구 명곡동',
#  '의창구 봉림동',
#  '마산회원구 합성2동']

# %%
dong2
# Out:
# ['마산합포구 현동',
#  '마산합포구 진전면',
#  '진해구 웅천동',
#  '진해구 풍호동',
#  '진해구 덕산동',
#  '마산합포구 진동면',
#  '진해구 자은동',
#  '마산합포구 진북면',
#  '진해구 경화동',
#  '마산합포구 구산면',
#  '의창구 대산면',
#  '마산회원구 회원2동',
#  '마산합포구 가포동',
#  '진해구 석동',
#  '마산합포구 완월동',
#  '성산구 웅남동',
# 49    229.595699  25.165399           2  1294.840705        9.995253        3
# 50     23.112601  25.409783           8   758.841272        4.980818        1
# 51     27.147065  25.588179          10   461.521520        4.915531        1
# 52     11.658056  25.587183          14   259.148472        1.862187        1
# 53     87.851228  25.165399          11   751.357779        2.897666        1
# 54    112.811080  25.162591          21  1165.624324       12.832720        0
#
#         address
# 0      마산합포구 현동
# 1     마산합포구 진전면
# 2        의창구 북면
# 3       진해구 웅천동
# 4       진해구 풍호동
# 5       진해구 덕산동
# 6     마산합포구 진동면
# 7       진해구 자은동
# 8     마산합포구 월영동
# 9       진해구 충무동
# 10    마산합포구 진북면
# 11      진해구 경화동
# 12      진해구 여좌동
# 13    마산합포구 구산면
# 14     진해구 웅동1동
# 15     진해구 웅동2동
# 16      진해구 태백동
# 17   마산회원구 양덕2동
# 18      진해구 병암동
# 19    마산합포구 교방동
# 20      의창구 대산면
# 21    마산합포구 합포동
# 22  마산합포구 반월중앙동
# 23   마산회원구 회원2동
# 24    마산합포구 오동동
# 25   마산회원구 합성1동
# 26    마산합포구 가포동
# 27      의창구 의창동
# 28       의창구 동읍
# 29     성산구 가음정동
# 30    마산회원구 석전동
# 31   마산회원구 회원1동
# 32       진해구 석동
# 33    마산회원구 내서읍
# 34    마산합포구 문화동
# 35    마산합포구 완월동
# 36    마산회원구 회성동
# 37      성산구 성주동
# 38      성산구 반송동
# 39      성산구 웅남동
# 40      성산구 사파동
# 41    마산합포구 자산동
# 42      의창구 팔룡동
# 43      성산구 용지동
# 44      성산구 상남동
# 45    마산회원구 봉암동
# 46   마산회원구 구암1동
# 47   마산회원구 양덕1동
# 48       진해구 이동
# 49   마산회원구 구암2동
# 50      성산구 중앙동
# 51      의창구 명곡동
# 52      의창구 봉림동
# 53   마산회원구 합성2동
# 54    마산합포구 산호동

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled = scaler.fit_transform(df1.iloc[:,:-2])
df = pd.DataFrame(scaled)
df.columns=df1.iloc[:,:-2].columns
df.head()
# Out:
#    traffic/area  avg_temp  dust_naver  f_pop/area  young_old/area
# 0     -0.851137 -0.642864    0.952794   -0.837322       -0.803678
# 1     -0.915072 -1.762805    0.952794   -0.912962       -0.997364
# 2     -0.902178 -0.008159   -1.376259   -0.856412       -0.843780
# 3     -0.838218 -1.091379    0.661663   -0.879428       -0.883515
# 4     -0.686662 -1.045658    0.952794   -0.608165       -0.214726

# %%
wcss = []
for i in range(1,11):
   model = KMeans(n_clusters = i, init = "k-means++")
   model.fit(df)
   wcss.append(model.inertia_)
plt.figure(figsize=(10,10))
plt.plot(range(1,11), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# C:\Users\lsb97_s4gev10\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
pca = PCA(2)
data = pca.fit_transform(df)

# %%
centers = np.array(model.cluster_centers_)
model = KMeans(n_clusters = 4, init = "k-means++")
label = model.fit_predict(data)
plt.figure(figsize=(5,5))
uniq = np.unique(label)
for i in uniq:
   plt.scatter(data[label == i , 0] , data[label == i , 1] , label = i)
plt.scatter(centers[:,0], centers[:,1], marker="x", color='k')
#This is done to find the centroid for each clusters.
plt.legend()
plt.show()

# %%
model.inertia_
# Out:
# 41.276655740311384

# %% [markdown]
# # standard보다 minmax가 낫다!
# # cluster4개 / minmax
