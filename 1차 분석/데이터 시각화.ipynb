# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt 
import platform 
from matplotlib import font_manager, rc

# %%
df = pd.read_csv('final.csv',encoding='UTF-8')
df
# Out:
#     Unnamed: 0    시군구    읍면동      address      area  traffic  traffic/area  \
# 0           22  마산합포구     현동     마산합포구 현동  1950.294     8201      4.205007
# 1           29  마산합포구    진전면    마산합포구 진전면  7846.994     4370      0.556901
# 2            4    의창구     북면       의창구 북면  7380.317     9540      1.292627
# 3           50    진해구    웅천동      진해구 웅천동  2888.601    14276      4.942185
# 4           44    진해구    풍호동      진해구 풍호동   813.615    11057     13.589966
# 5           47    진해구    덕산동      진해구 덕산동   279.267     8179     29.287384
# 6           25  마산합포구    진동면    마산합포구 진동면  3262.075     6943      2.128400
# 7           48    진해구    자은동      진해구 자은동   535.816    19137     35.715619
# 8           15  마산합포구    월영동    마산합포구 월영동   272.345     9509     34.915273
# 9           43    진해구    충무동      진해구 충무동  1833.321    26559     14.486825
# 10          26  마산합포구    진북면    마산합포구 진북면  4674.687     5279      1.129273
# ...

# %%
df.shape
# Out:
# (55, 18)

# %%
df.describe()
# Out:
#        Unnamed: 0         area       traffic  traffic/area   avg_temp  \
# count    55.00000    55.000000     55.000000     55.000000  55.000000
# mean     27.00000  1366.934782  12994.090909     52.770977  25.006063
# std      16.02082  1936.998406   4985.426276     57.585989   0.441874
# min       0.00000    57.876000   3157.000000      0.556901  23.727038
# 25%      13.50000   186.001500   9524.500000      8.276222  24.548234
# 50%      27.00000   522.862000  12640.000000     29.287384  25.162591
# 75%      40.50000  1697.677500  16053.000000     84.238720  25.165399
# max      54.00000  7846.994000  26559.000000    232.393393  25.623370
#
#         max_temp     t_dust  dust_airkorea  dust_naver          f_pop  \
# count  55.000000  37.000000      12.000000   55.000000      55.000000
# mean   35.078183  17.635584      27.698144   16.454545  156494.127273
# std     1.271438   7.932469       4.104553    6.933061  129971.940347
# ...

# %%
df.isnull().sum().to_frame('nan_count')
# Out:
#                 nan_count
# Unnamed: 0              0
# 시군구                     0
# 읍면동                     0
# address                 0
# area                    0
# traffic                 0
# traffic/area            0
# avg_temp                0
# max_temp                0
# t_dust                 18
# dust_airkorea          43
# dust_naver              0
# f_pop                   0
# f_pop/area              0
# p_total                 0
# young_old               0
# yo_ratio                0
# young_old/area          0

# %%
df['avg_temp'].describe()
# Out:
# count    55.000000
# mean     25.006063
# std       0.441874
# min      23.727038
# 25%      24.548234
# 50%      25.162591
# 75%      25.165399
# max      25.623370
# Name: avg_temp, dtype: float64

# %%
df['max_temp'].describe()
# Out:
# count    55.000000
# mean     35.078183
# std       1.271438
# min      32.500000
# 25%      34.000000
# 50%      34.900002
# 75%      36.550002
# max      37.500000
# Name: max_temp, dtype: float64

# %%
plt.figure(figsize=(10,5))


kde=sns.kdeplot(df['traffic']) 
kde.set_xlabel("창원시 교통량")



plt.show()

# %%
living = df[['traffic', 'max_temp','dust_naver', 'f_pop/area', 'young_old/area']]
living
# Out:
#     traffic   max_temp  dust_naver   f_pop/area  young_old/area
# 0      8201  35.099998          23    42.515128        1.239300
# 1      4370  34.000000          23     0.101695        0.084618
# 2      9540  37.500000           7    31.810829        1.000228
# 3     14276  33.599998          21    18.904999        0.763345
# 4     11057  33.599998          23   171.009630        4.750404
# 5      8179  33.599998          23   342.303244        4.934346
# 6      6943  34.000000          23    12.364216        0.495697
# 7     19137  33.599998          23   118.643340        5.238739
# 8      9509  34.900002          23  1228.291322       20.172942
# 9     26559  33.599998           3    91.674071        1.208735
# 10     5279  34.000000          23     8.485060        0.092627
# 11    11985  33.599998          23   169.836500        4.594056
# 12    10809  33.599998           3    72.418726        2.025391
# 13     3157  35.099998          23     1.105242        0.116735
# ...

# %%
ad = df.drop(['Unnamed: 0'], axis=1)
ad
# Out:
#       시군구    읍면동      address      area  traffic  traffic/area   avg_temp  \
# 0   마산합포구     현동     마산합포구 현동  1950.294     8201      4.205007  24.724592
# 1   마산합포구    진전면    마산합포구 진전면  7846.994     4370      0.556901  24.234239
# 2     의창구     북면       의창구 북면  7380.317     9540      1.292627  25.002491
# 3     진해구    웅천동      진해구 웅천동  2888.601    14276      4.942185  24.528216
# 4     진해구    풍호동      진해구 풍호동   813.615    11057     13.589966  24.548234
# 5     진해구    덕산동      진해구 덕산동   279.267     8179     29.287384  24.548234
# 6   마산합포구    진동면    마산합포구 진동면  3262.075     6943      2.128400  24.301857
# 7     진해구    자은동      진해구 자은동   535.816    19137     35.715619  24.548234
# 8   마산합포구    월영동    마산합포구 월영동   272.345     9509     34.915273  25.162591
# 9     진해구    충무동      진해구 충무동  1833.321    26559     14.486825  24.548234
# 10  마산합포구    진북면    마산합포구 진북면  4674.687     5279      1.129273  24.264991
# 11    진해구    경화동      진해구 경화동   306.483    11985     39.104942  24.548234
# ...

# %%
sns.heatmap(ad.corr(), cmap='YlGnBu', linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(12,10)
plt.show()

# %%
living1
# Out:
#       읍면동  traffic   max_temp   f_pop/area  dust_naver   f_pop  yo_ratio  \
# 0      현동     8201  35.099998    42.515128          23   82917  0.171285
# 1     진전면     4370  34.000000     0.101695          23     798  0.170256
# 2      북면     9540  37.500000    31.810829           7  234774  0.169916
# 3     웅천동    14276  33.599998    18.904999          21   54609  0.169811
# 4     풍호동    11057  33.599998   171.009630          23  139136  0.149679
# 5     덕산동     8179  33.599998   342.303244          23   95594  0.135911
# 6     진동면     6943  34.000000    12.364216          23   40333  0.132824
# 7     자은동    19137  33.599998   118.643340          23   63571  0.131525
# 8     월영동     9509  34.900002  1228.291322          23  334519  0.130810
# 9     충무동    26559  33.599998    91.674071           3  168068  0.130761
# 10    진북면     5279  34.000000     8.485060          23   39665  0.126942
# 11    경화동    11985  33.599998   169.836500          23   52052  0.126459
# ...

# %%
sns.barplot(x = "시군구", y = "traffic", data = df, palette = "Blues")
plt.title("창원 시군구 교통량")
# Out:
# Text(0.5, 1.0, '창원 시군구 교통량')

# %%
sns.barplot(x = "시군구", y = "traffic/area", data = df, palette = "Blues")
plt.title("창원 시군구 면적별 교통량")
# Out:
# Text(0.5, 1.0, '창원 시군구 면적별 교통량')

# %%
sns.barplot(x = "시군구", y = "max_temp", data = living, palette = "Blues")
plt.title("창원 시군구별 최대온도")
# Out:
# Text(0.5, 1.0, '창원 시군구별 최대온도')

# %%
sns.barplot(x = "시군구", y = "avg_temp", data = df, palette = "Blues")
plt.title("창원 시군구별 평균온도")
# Out:
# Text(0.5, 1.0, '창원 시군구별 평균온도')

# %%
sns.barplot(x = "시군구", y = "dust_naver", data = living, palette = "Blues")
plt.title("창원 시군구별 미세먼지량")
# Out:
# Text(0.5, 1.0, '창원 시군구별 미세먼지량')

# %%
sns.barplot(x = "시군구", y = "f_pop/area", data = df, palette =  'Blues')
plt.title("창원 시군구 지역별 유동인구량")
# Out:
# Text(0.5, 1.0, '창원 시군구 지역별 유동인구량')

# %%
sns.barplot(x = "시군구", y = "young_old/area", data = df, palette =  'Blues')
plt.title("창원 시군구 지역별 노약자비율")
# Out:
# Text(0.5, 1.0, '창원 시군구 지역별 노약자비율')

# %%
'traffic'    "traffic/area" "max_temp" "dust_naver" "f_pop/area"  "young_old/area"

# %%
traffic_df= df[['address', 'traffic']].sort_values(by = 'traffic', ascending = False)

# %%
traffic_df.head(10)
# '마산회원구'가 비교적 교통량이 많음.
# '주거시설 및 산업단지 위치와 밀접하게 연관'
# Out:
#        address  traffic
# 9      진해구 충무동    26559
# 25  마산회원구 합성1동    25760
# 36   마산회원구 회성동    21684
# 46  마산회원구 구암1동    20992
# 19   마산합포구 교방동    20752
# 7      진해구 자은동    19137
# 27     의창구 의창동    18463
# 38     성산구 반송동    18371
# 49  마산회원구 구암2동    17894
# 51     의창구 명곡동    17750

# %%
traffic_area= df[['address', "traffic/area"]].sort_values(by = "traffic/area", ascending = False)

# %%
traffic_area.head(10)
# '마산합포구','마산회원구'가 비교적 높음
# Out:
#         address  traffic/area
# 21    마산합포구 합포동    232.393393
# 49   마산회원구 구암2동    229.595699
# 31   마산회원구 회원1동    178.860615
# 47   마산회원구 양덕1동    152.633041
# 18      진해구 병암동    145.474116
# 16      진해구 태백동    143.295350
# 22  마산합포구 반월중앙동    122.285770
# 54    마산합포구 산호동    112.811080
# 41    마산합포구 자산동    106.681100
# 48       진해구 이동     95.418649

# %%
max_temp= df[['address', 'max_temp']].sort_values(by = "max_temp", ascending = False)

# %%
max_temp.head(10)
# 상위 10개 구 모두 의창구 및 성산구
# Out:
#     address   max_temp
# 2    의창구 북면  37.500000
# 27  의창구 의창동  36.900002
# 20  의창구 대산면  36.900002
# 52  의창구 봉림동  36.900002
# 51  의창구 명곡동  36.900002
# 44  성산구 상남동  36.900002
# 43  성산구 용지동  36.900002
# 42  의창구 팔룡동  36.900002
# 40  성산구 사파동  36.900002
# 39  성산구 웅남동  36.900002

# %%
avg_temp= df[['address', 'avg_temp']].sort_values(by = "avg_temp", ascending = False)

# %%
avg_temp.head(10)
# 상위 10개 구 모두 의창구 및 성산구
# Out:
#     address   avg_temp
# 39  성산구 웅남동  25.623370
# 27  의창구 의창동  25.588179
# 51  의창구 명곡동  25.588179
# 42  의창구 팔룡동  25.588179
# 52  의창구 봉림동  25.587183
# 44  성산구 상남동  25.587183
# 37  성산구 성주동  25.587183
# 38  성산구 반송동  25.587183
# 43  성산구 용지동  25.587183
# 40  성산구 사파동  25.587183

# %%
f_pop = df[['address', 'f_pop/area']].sort_values(by = "f_pop/area", ascending = False)

# %%
f_pop.head(10)
#  면적별 유동인구량
# '성산구', '마산합포구'가 비교적 높음
# Out:
#         address   f_pop/area
# 44      성산구 상남동  2933.900045
# 24    마산합포구 오동동  1382.100314
# 17   마산회원구 양덕2동  1331.198966
# 43      성산구 용지동  1323.236172
# 49   마산회원구 구암2동  1294.840705
# 8     마산합포구 월영동  1228.291322
# 22  마산합포구 반월중앙동  1218.602171
# 48       진해구 이동  1194.013090
# 54    마산합포구 산호동  1165.624324
# 29     성산구 가음정동  1142.072383

# %%
young_old = df[['address', "young_old/area"]].sort_values(by = "young_old/area", ascending = False)

# %%
young_old.head(10)
# Out:
#         address  young_old/area
# 17   마산회원구 양덕2동       22.064266
# 44      성산구 상남동       20.925417
# 8     마산합포구 월영동       20.172942
# 38      성산구 반송동       18.862803
# 22  마산합포구 반월중앙동       15.422644
# 31   마산회원구 회원1동       15.083065
# 29     성산구 가음정동       14.297023
# 21    마산합포구 합포동       14.254613
# 54    마산합포구 산호동       12.832720
# 24    마산합포구 오동동       11.640786

# %%
dust.head(10)
# 산업단지 위치와 연관되어 있음
# Out:
#       address  dust_naver
# 39    성산구 웅남동          24
# 45  마산회원구 봉암동          24
# 0    마산합포구 현동          23
# 26  마산합포구 가포동          23
# 1   마산합포구 진전면          23
# 18    진해구 병암동          23
# 32     진해구 석동          23
# 16    진해구 태백동          23
# 34  마산합포구 문화동          23
# 35  마산합포구 완월동          23

# %%
plt.figure(figsize=(10,5))


kde=sns.kdeplot(df['avg_temp']) 
kde.set_xlabel("평균온도")
kde.set_ylabel("비율")


plt.show()

# %%
plt.figure(figsize=(10,5))


kde=sns.kdeplot(df['max_temp']) 
kde.set_xlabel("최대온도")
kde.set_ylabel("비율")


plt.show()

# %%
df['avg_temp'].value_counts().nlargest(10)
# Out:
# 25.162591    12
# 24.548234    10
# 25.165399     8
# 25.587183     7
# 25.588179     3
# 24.724592     2
# 24.722464     1
# 24.528216     1
# 24.301857     1
# 25.002491     1
# Name: avg_temp, dtype: int64

# %%
plt.figure(figsize=(10,5))
df.plot.scatter(x='address',y='avg_temp')
plt.show()

# %%
plt.figure(figsize=(12,7))
df.plot.scatter(x='address',y='max_temp')
plt.show()

# %%
df_sorted_by_avg_temp = df.sort_values(by='avg_temp' ,ascending=False)
df_sorted_by_avg_temp.head(7).plot.scatter(x='읍면동',y='avg_temp')
plt.show()

# %%
df_sorted_by_max_temp = df.sort_values(by='max_temp' ,ascending=False)
df_sorted_by_max_temp.head(7).plot.scatter(x='읍면동',y='max_temp')
plt.figure(figsize=(10,3))
plt.show()

# %%
df_tdust = df.dropna(subset=['t_dust'])
df_tdust
# Out:
#     Unnamed: 0    시군구    읍면동      address      area  traffic  traffic/area  \
# 4           44    진해구    풍호동      진해구 풍호동   813.615    11057     13.589966
# 5           47    진해구    덕산동      진해구 덕산동   279.267     8179     29.287384
# 7           48    진해구    자은동      진해구 자은동   535.816    19137     35.715619
# 8           15  마산합포구    월영동    마산합포구 월영동   272.345     9509     34.915273
# 9           43    진해구    충무동      진해구 충무동  1833.321    26559     14.486825
# 11          51    진해구    경화동      진해구 경화동   306.483    11985     39.104942
# 12          53    진해구    여좌동      진해구 여좌동   522.862    10809     20.672759
# 15          42    진해구   웅동2동     진해구 웅동2동  1562.034     8319      5.325748
# 17          31  마산회원구   양덕2동   마산회원구 양덕2동   170.230    13725     80.626212
# 18          49    진해구    병암동      진해구 병암동    97.550    14191    145.474116
# 19          20  마산합포구    교방동    마산합포구 교방동   267.387    20752     77.610355
# ...

# %%
plt.figure(figsize=(10,5))


kde=sns.kdeplot(df_tdust['t_dust']) 
kde.set_xlabel("미세먼지 농도")
kde.set_ylabel("비율")


plt.show()

# %%
plt.figure(figsize=(12,7))
df_tdust.plot.scatter(x='address',y='t_dust')
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
df_sorted_by_tdust = df_tdust.sort_values(by='t_dust' ,ascending=False)
df_sorted_by_tdust.head(7).plot.scatter(x='읍면동',y='t_dust')
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
def draw_corrmat(df):
  y_corrmat = df.corr()
  f, ax = plt.subplots(figsize=(10,6))
  sns.heatmap(y_corrmat, vmax=.8, annot=True, fmt='.1f', square=True);
  
draw_corrmat(df)

# %%
def draw_top_corrmat(df,y,k):
  #k is choosing top k corrleation variables for the heatmap
  y_corrmat = df.corr()
  y_cols = y_corrmat.nlargest(k, y)[y].index
  cm = np.corrcoef(df[y_cols].values.T)
  sns.set(font_scale=1.25)
  f, ax = plt.subplots(figsize=(6,4))
  hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=y_cols.values, xticklabels=y_cols.values)
  plt.show()
    
draw_top_corrmat(df,'avg_temp',5)
draw_top_corrmat(df,'t_dust',4)
draw_top_corrmat(df,'dust_naver',5)
draw_top_corrmat(df,'traffic',5)
draw_top_corrmat(df,'p_total',5)

# %%
df
# Out:
#     Unnamed: 0    시군구    읍면동      address      area  traffic  traffic/area  \
# 0           22  마산합포구     현동     마산합포구 현동  1950.294     8201      4.205007
# 1           29  마산합포구    진전면    마산합포구 진전면  7846.994     4370      0.556901
# 2            4    의창구     북면       의창구 북면  7380.317     9540      1.292627
# 3           50    진해구    웅천동      진해구 웅천동  2888.601    14276      4.942185
# 4           44    진해구    풍호동      진해구 풍호동   813.615    11057     13.589966
# 5           47    진해구    덕산동      진해구 덕산동   279.267     8179     29.287384
# 6           25  마산합포구    진동면    마산합포구 진동면  3262.075     6943      2.128400
# 7           48    진해구    자은동      진해구 자은동   535.816    19137     35.715619
# 8           15  마산합포구    월영동    마산합포구 월영동   272.345     9509     34.915273
# 9           43    진해구    충무동      진해구 충무동  1833.321    26559     14.486825
# 10          26  마산합포구    진북면    마산합포구 진북면  4674.687     5279      1.129273
# ...

# %%
df1 = df.loc[:, ['address','traffic/area', 'max_temp', 'dust_naver', 'f_pop/area', 'yo_ratio','young_old/area']]
df1.sort_values(by='max_temp' ,ascending=False)
# Out:
#         address  traffic/area   max_temp  dust_naver   f_pop/area  yo_ratio  \
# 2        의창구 북면      1.292627  37.500000           7    31.810829  0.169916
# 27      의창구 의창동     22.419423  36.900002           9   319.749079  0.103705
# 20      의창구 대산면      1.981660  36.900002          17    15.160188  0.117705
# 52      의창구 봉림동     11.658056  36.900002          14   259.148472  0.075761
# 51      의창구 명곡동     27.147065  36.900002          10   461.521520  0.077429
# 44      성산구 상남동     76.593116  36.900002           8  2933.900045  0.086399
# 43      성산구 용지동     49.662191  36.900002          15  1323.236172  0.088997
# 42      의창구 팔룡동     11.226695  36.900002           7   388.689272  0.090639
# 40      성산구 사파동     19.178725  36.900002          15   438.931932  0.090792
# 39      성산구 웅남동      2.872190  36.900002          24    61.329073  0.091401
# 38      성산구 반송동     90.666811  36.900002          14  1109.781316  0.092498
# ...

# %%
draw_corrmat(df1)

# %%
df_sorted_by_tdust = df_tdust.sort_values(by='max_temp' ,ascending=False)
df.plot.scatter(x='시군구',y='max_temp')
plt.show()

# %%
df['max_temp']
# Out:
# 0     35.099998
# 1     34.000000
# 2     37.500000
# 3     33.599998
# 4     33.599998
# 5     33.599998
# 6     34.000000
# 7     33.599998
# 8     34.900002
# 9     33.599998
# 10    34.000000
# 11    33.599998
# 12    33.599998
# 13    35.099998
# 14    32.500000
# 15    33.599998
# 16    33.599998
# 17    34.900002
# 18    33.599998
# 19    34.900002
# 20    36.900002
# 21    34.900002
# 22    34.900002
# 23    34.900002
# 24    34.900002
# 25    34.900002
# 26    35.099998
# 27    36.900002
# 28    36.900002
# 29    36.900002
# 30    34.900002
# 31    34.900002
# 32    33.599998
# 33    34.900002
# 34    34.900002
# 35    34.900002
# 36    34.900002
# 37    36.900002
# 38    36.900002
# 39    36.900002
# 40    36.900002
# 41    34.900002
# 42    36.900002
# 43    36.900002
# 44    36.900002
# 45    34.900002
# 46    34.900002
# 47    34.900002
# 48    33.599998
# 49    34.900002
# 50    36.200001
# 51    36.900002
# 52    36.900002
# 53    34.900002
# 54    34.900002
# ...

# %%
df_sorted_by_tdust = df_tdust.sort_values(by='avg_temp' ,ascending=False)
df_sorted_by_tdust.plot.scatter(x='시군구',y='avg_temp')
plt.show()

# %%
df_sorted_by_tdust = df_tdust.sort_values(by='max_temp' ,ascending=False)
df_sorted_by_tdust.plot.scatter(x='시군구',y='max_temp')
plt.show()

# %%
df_sorted_by_tdust = df_tdust.sort_values(by='t_dust' ,ascending=False)
df_sorted_by_tdust.plot.scatter(x='시군구',y='t_dust')
plt.show()

# %%
df_sorted_by_tdust = df_tdust.sort_values(by='yo_ratio' ,ascending=False)
df_sorted_by_tdust.plot.scatter(x='시군구',y='yo_ratio')
plt.show()

# %%
df_sorted_by_tdust = df_tdust.sort_values(by='young_old/area' ,ascending=False)
df_sorted_by_tdust.plot.scatter(x='시군구',y='young_old/area')
plt.show()

# %%
df_sorted_by_tdust = df_tdust.sort_values(by='f_pop/area' ,ascending=False)
df_sorted_by_tdust.plot.scatter(x='시군구',y='f_pop/area')
plt.show()
